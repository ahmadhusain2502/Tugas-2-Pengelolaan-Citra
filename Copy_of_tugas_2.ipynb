# %%
# !pip install opencv-python

#Ahmad husain
#tugas 2
# Out:
# Requirement already satisfied: opencv-python in c:\users\notebook\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\notebook\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %%
from scipy import misc,ndimage 
from matplotlib import pyplot as plt 
 
face = misc.face() 
blurred_face = ndimage.gaussian_filter(face, sigma=3) 
 
fig, ax = plt.subplots(1, 2, figsize=(16, 8)) 
 
ax[0].imshow(face) 
ax[0].set_title("Original Image") 
ax[0].set_xticks([]) 
ax[0].set_yticks([]) 
 
 
ax[1].imshow(blurred_face) 
ax[1].set_title("Blurred Image") 
ax[1].set_xticks([]) 
ax[1].set_yticks([])
# Out:
# []

# %%
import cv2 as cv 
import numpy as np
import matplotlib.pyplot as plt 
 
image = cv.imread("kucing.jpg") 
 
fig, ax = plt.subplots(1, 3, figsize=(16, 8)) 
fig.tight_layout() 
 
# To conovolve the kernel on an image we can use cv.filter2D 
ax[0].imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB)) 
ax[0].set_title('Original Image') 
 
kernel_sharpening = np.array([[-1, -1, -1],
                              [-1, 9, -1],
                              [-1, -1, -1]])
kernel_sharpening_2 = np.array([[-1, -1, -1],
                                [-1, 10, -1],
                                [-1, -1, -1]])
sharpened = cv.filter2D(image, -1, kernel_sharpening) 
ax[1].imshow(cv.cvtColor(sharpened, 
cv.COLOR_BGR2RGB)) 
ax[1].set_title('Sharpened Kernel Image') 
 
sharpened_2 = cv.filter2D(image, -1, kernel_sharpening_2) 
ax[2].imshow(cv.cvtColor(sharpened_2, 
cv.COLOR_BGR2RGB)) 
ax[2].set_title('Sharpened Kernel Image 2') 
 
plt.show()
# warna hijau (RGB green = 0, 255, 0)
ijo = np.uint8([[[0,255,0 ]]])

# konversi ke HSV
hsv_ijo = cv2.cvtColor(ijo,cv2.COLOR_BGR2HSV)
print(hsv_ijo)
# Out:
# [[[ 60 255 255]]]

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4256\3985833426.py in <module>
#       1 from pylab import imshow, show
# ----> 2 import mahotas
#       3 import mahotas.demos
#       4 import numpy as np
#       5
#
# ModuleNotFoundError: No module named 'mahotas'

# %%
im.getbands( )
# Out:
# ('R', 'G', 'B')

# %%
im.size
# Out:
# (720, 960)

# %%
import base64 
with open("kucing.jpg", "rb") as image:
    image_string = base64.b64encode(image.read())

# %%
# warna hijau (RGB green = 0, 255, 0)
ijo = np.uint8([[[0,255,0 ]]])

# konversi ke HSV
hsv_ijo = cv2.cvtColor(ijo,cv2.COLOR_BGR2HSV)
print(hsv_ijo)
# Out:
# [[[ 60 255 255]]]
